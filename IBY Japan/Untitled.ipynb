# %%
import pandas as pd
import numpy as np
i=10

# %%
emotion_df=pd.read_csv(f"./emotion_data/{i}/emotion{i}.csv")
emotion_df=emotion_df.drop("image_seq",axis=1)
gaze_df=pd.read_csv(f"./emotion_data/{i}/gaze{i}.csv")

# %%
all=emotion_df.describe().iloc[1]
top_three_indices = np.argsort(all)[-3:][::-1]
top_three_emo = all.index[top_three_indices]

# %%
emo_1=top_three_emo[0]
emo_2=top_three_emo[1]
emo_3=top_three_emo[2]

# %%
gaze=gaze_df["gaze"].mean()
blink=gaze_df["blink"].sum()
eye_offset=gaze_df["eye_offset"].mean()

# %%
with open(f"transcripts/{i}.txt", "r") as file:
    speech = file.read()
transcript=pd.read_csv(f"transcript_data/{i}.csv")

# %%
positive=transcript["positive"].mean()
negative=transcript["negative"].mean()
confident=transcript["confident"].mean()
hesitant=transcript["hesitant"].mean()
concise=transcript["concise"].mean()
enthusiastic=transcript["enthusiastic"].mean()
speed=transcript["speech_speed"].mean()
id=transcript["id"]

# %%
prompt = f"""
As an HR hiring manager, you are evaluating a candidate based on data extracted from their introductory video. Your task is to provide three scores: an emotion score, a text score, and a combined weighted score. However, you should give a higher weight to the text data (70%) compared to the emotion data (30%) for the final evaluation. Based on these scores, you will decide whether to recommend hiring the candidate or not, supported by reasoning from the provided data.

Below is the candidate's data:

**Emotion Data:**
- Top three emotions exhibited throughout the video: {emo_1}, {emo_2}, {emo_3}
- Percentage of time the candidate maintained eye contact with the camera: {gaze*100}%
- Number of times the candidate blinked during the video: {blink}
- Average eye offset angle from the screen (degrees): {eye_offset}

**Text Data:**
- Transcript of the video: {speech}
- Average positive speech score: {positive}
- Average negative speech score: {negative}
- Average confidence score: {confident}
- Average hesitation score: {hesitant}
- Conciseness of responses score: {concise}
- Enthusiasm level score: {enthusiastic}
- Average speed of speech (words per second): {speed}

Your response should include:
1. **Emotion Score** (40% weight): An evaluation of the candidate’s emotional engagement based on the above data.
2. **Text Score** (60% weight): An assessment of the candidate’s speech content, delivery, and style, with a stronger emphasis on the transcript data.
3. **Combined Weighted Score**: A final score that combines emotion and text evaluations, with the text score weighted more heavily (60%).

Finally, **state whether you would hire the candidate or not**, giving clear reasons based on the scores and data provided.

**Do not answer with "I don't know" or "Here is the unified response."**
"""

# %%
print(prompt)
# Out:
# As an HR hiring manager, you are evaluating a candidate based on data extracted from their introductory video. Your task is to provide three scores: an emotion score, a text score, and a combined weighted score. However, you should give a higher weight to the text data (70%) compared to the emotion data (30%) for the final evaluation. Based on these scores, you will decide whether to recommend hiring the candidate or not, supported by reasoning from the provided data.
#
# Below is the candidate's data:
#
# **Emotion Data:**
# - Top three emotions exhibited throughout the video: fear, sad, neutral
# - Percentage of time the candidate maintained eye contact with the camera: 73.33333333333333%
# - Number of times the candidate blinked during the video: 15
# - Average eye offset angle from the screen (degrees): 11.49859
#
# **Text Data:**
# - Transcript of the video:  My name is Michael Ramos, I am from Patna, Bihar. I have done my schooling in Commerce and then  I went up to do my graduation in B.Com Honours. I have interned as an Accounting Associate  as well as a Tax Associate wherein I got the chance to apply all the knowledge that I had  learned in my B.Com to apply them in real life scenario. Apart from Academics, I have  been involved in a lot of extracurricular activities. I was the captain of the students  committee in my final school year and was also awarded the Best Student Award at the  end of the year. When I went up to college, I was the class representative which again  is the part of the students committee. Apart from that, I have been a part of Bad Scouts  and Guide for more than 5 years where I have completed several treks and was part of a  lot of activities that were based for social needs and for social cause. In my free time,  I like to read both fiction and non-fiction based on if I am feeling creative that day  or if I want to gain some info. The short term goal for me is to find a job where I  can apply the skill set and the knowledge that I have gained so far and build new skills  alongside. Whereas in the long term, I look for a role wherein I will be able to create  value. I look for bigger targets so that I can test myself. I need to figure myself during  the preliminary years so that when the superior targets are put, I am able to come up with  the best outcomes.
# - Average positive speech score: 0.5892669001922888
# - Average negative speech score: 0.22094799068701618
# - Average confidence score: 0.6198522983228459
# - Average hesitation score: 0.5206366580198792
# - Conciseness of responses score: 0.3856552571934812
# - Enthusiasm level score: 0.32550737656214657
# - Average speed of speech (words per second): 3.2485176794320747
#
# Your response should include:
# 1. **Emotion Score** (40% weight): An evaluation of the candidate’s emotional engagement based on the above data.
# 2. **Text Score** (60% weight): An assessment of the candidate’s speech content, delivery, and style, with a stronger emphasis on the transcript data.
# 3. **Combined Weighted Score**: A final score that combines emotion and text evaluations, with the text score weighted more heavily (60%).
#
# Finally, **state whether you would hire the candidate or not**, giving clear reasons based on the scores and data provided.
#
# **Do not answer with "I don't know" or "Here is the unified response."**

# %%
transcript
# Out:
#     id  seek  start    end                                               text  \
# 0    0     0   0.00   6.04   My name is Michael Ramos, I am from Patna, Bi...
# 1    1     0   6.04  12.08   I went up to do my graduation in B.Com Honour...
# 2    2     0  12.08  16.68   as well as a Tax Associate wherein I got the ...
# 3    3     0  16.68  22.56   learned in my B.Com to apply them in real lif...
# 4    4     0  22.56  26.76   been involved in a lot of extracurricular act...
# 5    5  2676  26.76  30.76   committee in my final school year and was als...
# 6    6  2676  30.76  37.04   end of the year. When I went up to college, I...
# 7    7  2676  37.04  42.32   is the part of the students committee. Apart ...
# 8    8  2676  42.32  47.40   and Guide for more than 5 years where I have ...
# 9    9  2676  47.40  53.52   lot of activities that were based for social ...
# 10  10  5352  53.52  58.68   I like to read both fiction and non-fiction b...
# 11  11  5352  58.68  63.48   or if I want to gain some info. The short ter...
# 12  12  5352  63.48  69.16   can apply the skill set and the knowledge tha...
# 13  13  5352  69.16  75.40   alongside. Whereas in the long term, I look f...
# 14  14  5352  75.40  81.68   value. I look for bigger targets so that I ca...
# 15  15  8168  81.84  88.84   the preliminary years so that when the superi...
# 16  16  8168  88.84  89.72                                 the best outcomes.
#
#                                                tokens  temperature  \
# 0   [50364, 1222, 1315, 307, 49328, 2786, 11, 286,...          0.0
# 1   [50666, 286, 1437, 493, 281, 360, 452, 15652, ...          0.0
# 2   [50968, 382, 731, 382, 257, 23263, 28520, 4353...          0.0
# 3   [51198, 3264, 294, 452, 363, 13, 14627, 281, 3...          0.0
# 4   [51492, 668, 3288, 294, 257, 688, 295, 1279, 1...          0.0
# 5   [50364, 7482, 294, 452, 2572, 1395, 1064, 293,...          0.0
# 6   [50564, 917, 295, 264, 1064, 13, 1133, 286, 14...          0.0
# 7   [50878, 307, 264, 644, 295, 264, 1731, 7482, 1...          0.0
# 8   [51142, 293, 18727, 337, 544, 813, 1025, 924, ...          0.0
# 9   [51396, 688, 295, 5354, 300, 645, 2361, 337, 2...          0.0
# 10  [50364, 286, 411, 281, 1401, 1293, 13266, 293,...          0.0
# 11  [50622, 420, 498, 286, 528, 281, 6052, 512, 13...          0.0
# 12  [50862, 393, 3079, 264, 5389, 992, 293, 264, 3...          0.0
# 13  [51146, 12385, 13, 13813, 294, 264, 938, 1433,...          0.0
# 14  [51458, 2158, 13, 286, 574, 337, 3801, 12911, ...          0.0
# 15  [50372, 264, 28817, 924, 370, 300, 562, 264, 1...          0.0
# 16               [50722, 264, 1151, 10070, 13, 50766]          0.0
#
#     avg_logprob  compression_ratio  no_speech_prob  positive  negative  \
# 0     -0.331398           1.622711        0.543254  0.457349  0.206400
# 1     -0.331398           1.622711        0.543254  0.532671  0.222764
# 2     -0.331398           1.622711        0.543254  0.714758  0.117540
# 3     -0.331398           1.622711        0.543254  0.606619  0.132189
# 4     -0.331398           1.622711        0.543254  0.629161  0.139293
# 5     -0.307686           1.700389        0.160006  0.820358  0.089789
# 6     -0.307686           1.700389        0.160006  0.365052  0.422054
# 7     -0.307686           1.700389        0.160006  0.042917  0.879557
# 8     -0.307686           1.700389        0.160006  0.424447  0.332483
# 9     -0.307686           1.700389        0.160006  0.844495  0.094716
# 10    -0.263795           1.691120        0.036832  0.749994  0.086514
# 11    -0.263795           1.691120        0.036832  0.405512  0.282121
# 12    -0.263795           1.691120        0.036832  0.737435  0.063301
# 13    -0.263795           1.691120        0.036832  0.594038  0.206492
# 14    -0.263795           1.691120        0.036832  0.587039  0.207191
# 15    -0.395755           1.197802        0.101272  0.542674  0.259974
# 16    -0.395755           1.197802        0.101272  0.963019  0.013739
#
#      neutral  confident  hesitant   concise  enthusiastic  speech_speed
# 0   0.336251   0.888680  0.881647  0.705780      0.623946      2.980132
# 1   0.244564   0.732424  0.750270  0.620743      0.367078      2.814570
# 2   0.167701   0.764776  0.384795  0.388321      0.316069      4.130435
# 3   0.261192   0.829503  0.472637  0.776919      0.383717      2.721088
# 4   0.231547   0.732535  0.387367  0.098993      0.349005      3.571429
# 5   0.089853   0.859685  0.761701  0.571727      0.618871      4.000000
# 6   0.212895   0.632067  0.808151  0.604331      0.282800      2.707006
# 7   0.077527   0.680328  0.840056  0.415379      0.228578      3.409091
# 8   0.243070   0.852568  0.424886  0.240302      0.476454      3.543307
# 9   0.060790   0.182144  0.100494  0.035973      0.239480      2.777778
# 10  0.163491   0.231128  0.316820  0.151902      0.268992      3.294574
# 11  0.312368   0.401130  0.696276  0.351400      0.138355      4.375000
# 12  0.199264   0.821343  0.204142  0.422417      0.254029      3.169014
# 13  0.199470   0.455449  0.631635  0.221028      0.127612      2.884615
# 14  0.205771   0.127398  0.436416  0.020206      0.275292      2.866242
# 15  0.197352   0.539320  0.450221  0.284381      0.104140      2.571429
# 16  0.023242   0.807010  0.303308  0.646336      0.479207      3.409091
